# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df_dataset = pd.read_csv('/mnt/bigDisk/EDR/unzip_FilelessPcap_label/FilelessPacp_label_dataset/total/total_merged.csv')

# %%
df_dataset.shape
# Out:
# (866619, 16)

# %%
df_dataset.sample(5)
# Out:
#         TCP_UPLOAD_PACKETS  TCP_DOWNLOAD_PACKETS  TCP_UPLOAD_BYTES  \
# 473352                 1.0                   1.0               0.0
# 658954                 1.0                   1.0               0.0
# 156970                 1.0                   1.0               0.0
# 133199                 1.0                   1.0               0.0
# 124675                 1.0                   1.0               0.0
#
#         TCP_DOWNLOAD_BYTES  UDP_UPLOAD_PACKETS  UDP_DOWNLOAD_PACKETS  \
# 473352                 0.0                 0.0                   0.0
# 658954                 0.0                 0.0                   0.0
# 156970                 0.0                 0.0                   0.0
# 133199                 0.0                 0.0                   0.0
# 124675                 0.0                 0.0                   0.0
#
#         UDP_UPLOAD_BYTES  UDP_DOWNLOAD_BYTES  DIRECTION  TOTAL_DNS_NUMBER  \
# ...

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 866619 entries, 0 to 866618
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   TCP_UPLOAD_PACKETS    866619 non-null  float64
#  1   TCP_DOWNLOAD_PACKETS  866619 non-null  float64
#  2   TCP_UPLOAD_BYTES      866619 non-null  float64
#  3   TCP_DOWNLOAD_BYTES    866619 non-null  float64
#  4   UDP_UPLOAD_PACKETS    866619 non-null  float64
#  5   UDP_DOWNLOAD_PACKETS  866619 non-null  float64
#  6   UDP_UPLOAD_BYTES      866619 non-null  float64
#  7   UDP_DOWNLOAD_BYTES    866619 non-null  float64
#  8   DIRECTION             866619 non-null  float64
#  9   TOTAL_DNS_NUMBER      866619 non-null  float64
#  10  TOTAL_HOST_NUMBER     866619 non-null  float64
#  11  SOURCE_IP             866619 non-null  float64
#  12  DESTINATION_IP        866619 non-null  float64
#  13  START_TIME            866619 non-null  float64
# ...

# %%
df_dataset.describe()
# Out:
#        TCP_UPLOAD_PACKETS  TCP_DOWNLOAD_PACKETS  TCP_UPLOAD_BYTES  \
# count       866619.000000         866619.000000     866619.000000
# mean             0.981134              0.985304         11.211484
# std              0.666203              0.656986        123.458892
# min              0.000000              0.000000          0.000000
# 25%              1.000000              1.000000          0.000000
# 50%              1.000000              1.000000          0.000000
# 75%              1.000000              1.000000          0.000000
# max            179.000000            179.000000      75715.000000
#
#        TCP_DOWNLOAD_BYTES  UDP_UPLOAD_PACKETS  UDP_DOWNLOAD_PACKETS  \
# count       866619.000000       866619.000000         866619.000000
# mean             6.041019            0.083581              0.001975
# std             63.509569            0.284124              0.044558
# min              0.000000            0.000000              0.000000
# ...

# %%
pd.DataFrame(df_dataset).isnull().sum()
# Out:
# TCP_UPLOAD_PACKETS      0
# TCP_DOWNLOAD_PACKETS    0
# TCP_UPLOAD_BYTES        0
# TCP_DOWNLOAD_BYTES      0
# UDP_UPLOAD_PACKETS      0
# UDP_DOWNLOAD_PACKETS    0
# UDP_UPLOAD_BYTES        0
# UDP_DOWNLOAD_BYTES      0
# DIRECTION               0
# TOTAL_DNS_NUMBER        0
# TOTAL_HOST_NUMBER       0
# SOURCE_IP               0
# DESTINATION_IP          0
# START_TIME              0
# STAGE                   0
# LABEL                   0
# dtype: int64

# %%
df_dataset.columns
# Out:
# Index(['TCP_UPLOAD_PACKETS', 'TCP_DOWNLOAD_PACKETS', 'TCP_UPLOAD_BYTES',
#        'TCP_DOWNLOAD_BYTES', 'UDP_UPLOAD_PACKETS', 'UDP_DOWNLOAD_PACKETS',
#        'UDP_UPLOAD_BYTES', 'UDP_DOWNLOAD_BYTES', 'DIRECTION',
#        'TOTAL_DNS_NUMBER', 'TOTAL_HOST_NUMBER', 'SOURCE_IP', 'DESTINATION_IP',
#        'START_TIME', 'STAGE', 'LABEL'],
#       dtype='object')

# %%
ylabel = df_dataset['LABEL']

# %%
dropFeature = ['LABEL']
df_dataset = df_dataset.drop(dropFeature, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_dataset, ylabel, test_size=0.33, random_state=42)

# %% [markdown]
# # RandomForest
# Acc 0.9982

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn import ensemble, preprocessing, metrics
from sklearn.metrics import confusion_matrix

# build model
forest = ensemble.RandomForestClassifier(n_estimators = 100)

# train
forest_fit = forest.fit(X_train, y_train)

# predict
test_y_predicted = forest.predict(X_test)

# Acc
accuracy = metrics.accuracy_score(y_test, test_y_predicted)
print("Acc: " + str(accuracy))
# Out:
# Acc: 0.9982446631816354

# %%
confusion_matrix(y_test, test_y_predicted)
# Out:
# array([[276236,    219],
#        [   283,   9247]])

# %% [markdown]
# # XGboost
# Acc 0.9982

# %%
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix

# build model
xgboostModel = XGBClassifier(n_estimators=100, learning_rate= 0.3)

# train
xgboostModel.fit(X_train, y_train)

# predict
predicted = xgboostModel.predict(X_test)

# Acc
#print('trainset: ',xgboostModel.score(X_train,y_train))
print('Acc: ',xgboostModel.score(X_test,y_test))
# Out:
# Acc:  0.998276133363638

# %%
confusion_matrix(y_test, predicted)
# Out:
# array([[276308,    147],
#        [   346,   9184]])

# %% [markdown]
# # Balance training set experiment

# %%
df_dataset = pd.read_csv('/mnt/bigDisk/EDR/unzip_FilelessPcap_label/FilelessPacp_label_dataset/total/total_merged.csv')

# %%
df_benigh = df_dataset[df_dataset['LABEL']==0].sample(29197)
df_malware = df_dataset[df_dataset['LABEL']==1].sample(29197)
df_dataset_balance = pd.concat([df_benigh, df_malware],axis=0)
df_dataset_balance
# Out:
#         TCP_UPLOAD_PACKETS  TCP_DOWNLOAD_PACKETS  TCP_UPLOAD_BYTES  \
# 764290                 0.0                   0.0               0.0
# 248504                 1.0                   1.0               0.0
# 505534                 1.0                   1.0               0.0
# 594699                 0.0                   0.0               0.0
# 292159                 1.0                   1.0               0.0
# ...                    ...                   ...               ...
# 649342                 1.0                   1.0             539.0
# 569638                 1.0                   1.0             541.0
# 372961                 1.0                   1.0             486.0
# 456628                 1.0                   1.0             541.0
# 81033                  1.0                   0.0             497.0
#
#         TCP_DOWNLOAD_BYTES  UDP_UPLOAD_PACKETS  UDP_DOWNLOAD_PACKETS  \
# 764290                 0.0                 1.0                   0.0
# ...

# %%
ylabel_balance = df_dataset_balance['LABEL']
dropFeature = ['LABEL']
df_dataset_balance = df_dataset_balance.drop(dropFeature, axis=1)
X_train_balance, X_test_balance, y_train_balance, y_test_balance = train_test_split(df_dataset_balance, ylabel_balance, test_size=0.33, random_state=42)

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn import ensemble, preprocessing, metrics
from sklearn.metrics import confusion_matrix

# build model
forest = ensemble.RandomForestClassifier(n_estimators = 100)

# train
forest_fit = forest.fit(X_train_balance, y_train_balance)

# predict
test_y_predicted = forest.predict(X_test_balance)

# Acc
accuracy = metrics.accuracy_score(y_test_balance, test_y_predicted)
print("Acc: " + str(accuracy))
# Out:
# Acc: 0.9900368429246017

# %%
confusion_matrix(y_test_balance, test_y_predicted)
# Out:
# array([[9528,   63],
#        [ 129, 9551]])

# %%
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix

# build model
xgboostModel = XGBClassifier(n_estimators=100, learning_rate= 0.3)

# train
xgboostModel.fit(X_train_balance, y_train_balance)

# predict
predicted = xgboostModel.predict(X_test_balance)

# Acc
#print('trainset: ',xgboostModel.score(X_train,y_train))
print('Acc: ',xgboostModel.score(X_test_balance,y_test_balance))
# Out:
# Acc:  0.9895698199366925

# %%
confusion_matrix(y_test_balance, predicted)
# Out:
# array([[9535,   56],
#        [ 145, 9535]])

# %%
from sklearn.model_selection import cross_val_score
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
# knn
knn = KNeighborsClassifier(n_neighbors = 10)
scores = cross_val_score(knn, X_train_balance, y_train_balance, cv = 5, scoring = 'accuracy')
print(scores)
print(scores.mean())
# Out:
# [0.86172524 0.86734824 0.86543131 0.86145194 0.86477505]
# 0.8641463572394598

# %%
k_range = range(1,31)
k_scores = []
for k_number in k_range:
    knn = KNeighborsClassifier(n_neighbors=k_number)
    scores = cross_val_score(knn, X_train_balance, y_train_balance, cv = 5, scoring = 'accuracy')
    k_scores.append(scores.mean())

# %%
plt.plot(k_range,k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
